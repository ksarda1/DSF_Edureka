# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

# %%
data = pd.read_csv('letterCG.bin',sep=' ')
data = data.dropna(axis=1)
data
# Out:
#      Class  x-box  y-box  width  high  Unnamed: 5  onpix  x-bar  y-bar  x2bar  \
# 0        C      4     10      5     8           2      5      7      7     10
# 1        C      3      5      4     4           2      4      8      5      7
# 2        G      5     10      6     7           3      8      7      8      8
# 3        C      5      9      6     7           4      3      8      6      7
# 4        G      4      8      5     6           3      6      6      7      6
# ...    ...    ...    ...    ...   ...         ...    ...    ...    ...    ...
# 1504     C      5     10      6     8           4      5      8      9      9
# 1505     C      6     11      7     8           4      6      7     10      9
# 1506     G      5      9      6     7           4      6      7      6      6
# 1507     C      6     11      7     8           5      5      8      7      6
# 1508     C      5     10      5     8           3      6      8      7      7
#
# ...

# %%
X = data.drop(['Class'],axis=1)
y = data.Class

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
accuracy = []
for estimators in range(1,17) :
    model = AdaBoostClassifier(n_estimators=estimators).fit(X_train,y_train)
    accuracy.append(model.score(X_test,y_test))
plt.plot(accuracy)

# %%
accuracy = []
for estimators in range(1,17) :
    model = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=2),n_estimators=estimators).fit(X_train,y_train)
    accuracy.append(model.score(X_test,y_test))
plt.plot(accuracy)
